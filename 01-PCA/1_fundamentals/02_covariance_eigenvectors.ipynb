# %% [markdown]
# # Covariance, Eigenvectors, and Eigenvalues
#
# ## Introduction
#
# In the previous notebook, we learned that PCA finds directions of maximum variance. But how does it find these directions mathematically?
#
# The answer involves three key concepts:
# 1. **Covariance**: How features vary together
# 2. **Eigenvectors**: The principal component directions
# 3. **Eigenvalues**: The amount of variance in each direction
#
# Don't worry if these sound complicated - we'll build intuition step by step!

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
np.random.seed(42)

print("✓ Ready to explore covariance and eigenvectors!")

# %% [markdown]
# ## 1. Covariance: How Features Vary Together
#
# ### What is Covariance?
#
# While variance measures how ONE feature varies, **covariance** measures how TWO features vary **together**.
#
# **Formula**:
# $$\text{Cov}(X, Y) = \frac{1}{n}\sum_{i=1}^{n}(x_i - \bar{x})(y_i - \bar{y})$$
#
# **Interpretation**:
# - **Positive covariance**: When X increases, Y tends to increase
# - **Negative covariance**: When X increases, Y tends to decrease
# - **Zero covariance**: X and Y are uncorrelated
